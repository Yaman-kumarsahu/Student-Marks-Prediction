# %% [markdown]
# # **Students' Marks Prediction and Improvement**

# %% [markdown]
# ## Import Dependencies

# %%
import pandas as pd
import numpy as np
import os
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
import xgboost as xgb
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, classification_report
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
import joblib

# %% [markdown]
# ## Setting up Directories and Environments

# %%
list_of_data_path = os.listdir('dataset')
list_of_data_path = ['dataset/' + i for i in list_of_data_path]

sub_name_list = []
classification_report_dict = {
    'svm_nfp' : {},
    'svm_ros' : {},
    'svm_rus' : {},
    'xgb_nfp' : {},
    'xgb_ros' : {},
    'xgb_rus' : {}
}
temp_dict = {}

# %% [markdown]
# ## SVM Classifier

# %% [markdown]
# ### With No Further Processing

# %%
for i in range(len(list_of_data_path)):
  data = pd.read_excel(list_of_data_path[i], index_col=0)
  data.replace(-1, 0, inplace = True)
  sub_name = list_of_data_path[i].split('/')[3].split('_')[1].split('.')[0]
  sub_name_list.append(sub_name)

  passes = pd.Series(data['ese'] >= 40)
  data = pd.concat([data, passes.rename("Result")], axis=1)

  data.replace({'Result' : {True : 1, False : 0}}, inplace = True)

  X = data[['att','ct1','ct2','ta']]
  y = data['Result']
  X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.3 , random_state = 2529)

  model = LogisticRegression()
  model.fit(X_train, y_train)
  y_pred  = model.predict(X_test)

  temp_dict = classification_report(y_test, y_pred, output_dict=True)
  classification_report_dict['svm_nfp'][sub_name + '_model'] = round(temp_dict['accuracy'] * 100, 2)

  print(str(i+1) + '. ' + sub_name)
  print('\nConfusion Matrix :\n')
  print(confusion_matrix(y_test, y_pred))
  print('\n\nClassification Report :\n')
  print(classification_report(y_test, y_pred))
  print('-' * 55)
  print('\n')
# Out:
# 1. ccwt
#
# Confusion Matrix :
#
# [[ 5  3]
#  [ 4 21]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.56      0.62      0.59         8
#            1       0.88      0.84      0.86        25
#
#     accuracy                           0.79        33
#    macro avg       0.72      0.73      0.72        33
# weighted avg       0.80      0.79      0.79        33
#
# -------------------------------------------------------
#
#
# 2. mca
#
# Confusion Matrix :
#
# [[ 1  8]
#  [ 4 19]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.20      0.11      0.14         9
#            1       0.70      0.83      0.76        23
#
#     accuracy                           0.62        32
#    macro avg       0.45      0.47      0.45        32
# weighted avg       0.56      0.62      0.59        32
#
# -------------------------------------------------------
#
#
# 3. java
#
# Confusion Matrix :
#
# [[ 4  7]
#  [ 2 20]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.36      0.47        11
#            1       0.74      0.91      0.82        22
#
#     accuracy                           0.73        33
#    macro avg       0.70      0.64      0.64        33
# weighted avg       0.72      0.73      0.70        33
#
# -------------------------------------------------------
#
#
# 4. ai
#
# Confusion Matrix :
#
# [[ 1  9]
#  [ 1 19]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.10      0.17        10
#            1       0.68      0.95      0.79        20
#
#     accuracy                           0.67        30
#    macro avg       0.59      0.53      0.48        30
# weighted avg       0.62      0.67      0.58        30
#
# -------------------------------------------------------
#
#
# 5. pslb
#
# Confusion Matrix :
#
# [[14  4]
#  [ 8  7]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.64      0.78      0.70        18
#            1       0.64      0.47      0.54        15
#
#     accuracy                           0.64        33
#    macro avg       0.64      0.62      0.62        33
# weighted avg       0.64      0.64      0.63        33
#
# -------------------------------------------------------
#
#
# 6. np
#
# Confusion Matrix :
#
# [[ 2  3]
#  [ 2 25]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.40      0.44         5
#            1       0.89      0.93      0.91        27
#
#     accuracy                           0.84        32
#    macro avg       0.70      0.66      0.68        32
# weighted avg       0.83      0.84      0.84        32
#
# -------------------------------------------------------
#
#
# 7. dsa
#
# Confusion Matrix :
#
# [[ 4  9]
#  [ 4 16]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.31      0.38        13
#            1       0.64      0.80      0.71        20
#
#     accuracy                           0.61        33
#    macro avg       0.57      0.55      0.55        33
# weighted avg       0.58      0.61      0.58        33
#
# -------------------------------------------------------
#
#
# 8. os
#
# Confusion Matrix :
#
# [[ 6  7]
#  [ 2 18]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.46      0.57        13
#            1       0.72      0.90      0.80        20
#
#     accuracy                           0.73        33
#    macro avg       0.73      0.68      0.69        33
# weighted avg       0.73      0.73      0.71        33
#
# -------------------------------------------------------
#
#
# 9. cs
#
# Confusion Matrix :
#
# [[21  3]
#  [ 6  3]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.78      0.88      0.82        24
#            1       0.50      0.33      0.40         9
#
#     accuracy                           0.73        33
#    macro avg       0.64      0.60      0.61        33
# weighted avg       0.70      0.73      0.71        33
#
# -------------------------------------------------------
#
#
# 10. deld
#
# Confusion Matrix :
#
# [[23  2]
#  [ 5  3]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.82      0.92      0.87        25
#            1       0.60      0.38      0.46         8
#
#     accuracy                           0.79        33
#    macro avg       0.71      0.65      0.66        33
# weighted avg       0.77      0.79      0.77        33
#
# -------------------------------------------------------
#
#
# 11. cn
#
# Confusion Matrix :
#
# [[19  4]
#  [ 5  5]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.79      0.83      0.81        23
#            1       0.56      0.50      0.53        10
#
#     accuracy                           0.73        33
#    macro avg       0.67      0.66      0.67        33
# weighted avg       0.72      0.73      0.72        33
#
# -------------------------------------------------------
#
#
# 12. cm
#
# Confusion Matrix :
#
# [[ 5  7]
#  [ 4 17]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.56      0.42      0.48        12
#            1       0.71      0.81      0.76        21
#
#     accuracy                           0.67        33
#    macro avg       0.63      0.61      0.62        33
# weighted avg       0.65      0.67      0.65        33
#
# -------------------------------------------------------
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 13. iwt
#
# Confusion Matrix :
#
# [[ 0  7]
#  [ 0 23]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         7
#            1       0.77      1.00      0.87        23
#
#     accuracy                           0.77        30
#    macro avg       0.38      0.50      0.43        30
# weighted avg       0.59      0.77      0.67        30
#
# -------------------------------------------------------
#
#
# 14. sepm
#
# Confusion Matrix :
#
# [[ 6  4]
#  [ 1 22]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.60      0.71        10
#            1       0.85      0.96      0.90        23
#
#     accuracy                           0.85        33
#    macro avg       0.85      0.78      0.80        33
# weighted avg       0.85      0.85      0.84        33
#
# -------------------------------------------------------
#
#
# 15. imt
#
# Confusion Matrix :
#
# [[ 0  7]
#  [ 0 23]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         7
#            1       0.77      1.00      0.87        23
#
#     accuracy                           0.77        30
#    macro avg       0.38      0.50      0.43        30
# weighted avg       0.59      0.77      0.67        30
#
# -------------------------------------------------------
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 16. dwt
#
# Confusion Matrix :
#
# [[6 9]
#  [7 8]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.46      0.40      0.43        15
#            1       0.47      0.53      0.50        15
#
#     accuracy                           0.47        30
#    macro avg       0.47      0.47      0.46        30
# weighted avg       0.47      0.47      0.46        30
#
# -------------------------------------------------------
#
#
# 17. cc
#
# Confusion Matrix :
#
# [[ 4  8]
#  [ 1 19]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.33      0.47        12
#            1       0.70      0.95      0.81        20
#
#     accuracy                           0.72        32
#    macro avg       0.75      0.64      0.64        32
# weighted avg       0.74      0.72      0.68        32
#
# -------------------------------------------------------
#
#
# 18. cg
#
# Confusion Matrix :
#
# [[ 9 11]
#  [ 2 11]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.82      0.45      0.58        20
#            1       0.50      0.85      0.63        13
#
#     accuracy                           0.61        33
#    macro avg       0.66      0.65      0.60        33
# weighted avg       0.69      0.61      0.60        33
#
# -------------------------------------------------------
#
#
# 19. m3
#
# Confusion Matrix :
#
# [[ 9  7]
#  [ 3 14]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.56      0.64        16
#            1       0.67      0.82      0.74        17
#
#     accuracy                           0.70        33
#    macro avg       0.71      0.69      0.69        33
# weighted avg       0.71      0.70      0.69        33
#
# -------------------------------------------------------
#
#
# 20. crp
#
# Confusion Matrix :
#
# [[ 2  7]
#  [ 3 20]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.40      0.22      0.29         9
#            1       0.74      0.87      0.80        23
#
#     accuracy                           0.69        32
#    macro avg       0.57      0.55      0.54        32
# weighted avg       0.64      0.69      0.66        32
#
# -------------------------------------------------------
#
#
# 21. csa
#
# Confusion Matrix :
#
# [[12  6]
#  [ 5 10]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.71      0.67      0.69        18
#            1       0.62      0.67      0.65        15
#
#     accuracy                           0.67        33
#    macro avg       0.67      0.67      0.67        33
# weighted avg       0.67      0.67      0.67        33
#
# -------------------------------------------------------
#
#
# 22. be
#
# Confusion Matrix :
#
# [[13  3]
#  [ 9  8]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.59      0.81      0.68        16
#            1       0.73      0.47      0.57        17
#
#     accuracy                           0.64        33
#    macro avg       0.66      0.64      0.63        33
# weighted avg       0.66      0.64      0.63        33
#
# -------------------------------------------------------
#
#
# 23. ppc
#
# Confusion Matrix :
#
# [[ 0 11]
#  [ 0 21]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        11
#            1       0.66      1.00      0.79        21
#
#     accuracy                           0.66        32
#    macro avg       0.33      0.50      0.40        32
# weighted avg       0.43      0.66      0.52        32
#
# -------------------------------------------------------
#
#
# 24. dms
#
# Confusion Matrix :
#
# [[16  5]
#  [ 9  3]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.64      0.76      0.70        21
#            1       0.38      0.25      0.30        12
#
#     accuracy                           0.58        33
#    macro avg       0.51      0.51      0.50        33
# weighted avg       0.54      0.58      0.55        33
#
# -------------------------------------------------------
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 25. ada
#
# Confusion Matrix :
#
# [[11  4]
#  [ 5 13]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.69      0.73      0.71        15
#            1       0.76      0.72      0.74        18
#
#     accuracy                           0.73        33
#    macro avg       0.73      0.73      0.73        33
# weighted avg       0.73      0.73      0.73        33
#
# -------------------------------------------------------
#
#
# 26. mp
#
# Confusion Matrix :
#
# [[14  5]
#  [ 2 12]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.74      0.80        19
#            1       0.71      0.86      0.77        14
#
#     accuracy                           0.79        33
#    macro avg       0.79      0.80      0.79        33
# weighted avg       0.80      0.79      0.79        33
#
# -------------------------------------------------------

# %% [markdown]
# ### With Random OverSampling

# %%
for i in range(len(list_of_data_path)):
  data = pd.read_excel(list_of_data_path[i], index_col=0)
  data.replace(-1, 0, inplace = True)
  sub_name = list_of_data_path[i].split('/')[3].split('_')[1].split('.')[0]

  passes = pd.Series(data['ese'] >= 40)
  data = pd.concat([data, passes.rename("Result")], axis=1)

  data.replace({'Result' : {True : 1, False : 0}}, inplace = True)

  X = data[['att','ct1','ct2','ta']]
  y = data['Result']
  ros = RandomOverSampler(random_state = 12529)
  X_ros, y_ros = ros.fit_resample(X, y)

  X_train, X_test, y_train, y_test = train_test_split(X_ros, y_ros, test_size = 0.3 , random_state = 2529)

  model = LogisticRegression()
  model.fit(X_train, y_train)
  y_pred  = model.predict(X_test)

  temp_dict = classification_report(y_test, y_pred, output_dict=True)
  classification_report_dict['svm_ros'][sub_name + '_model'] = round(temp_dict['accuracy'] * 100, 2)

  print(str(i+1) + '. ' + sub_name)
  print('\nConfusion Matrix :\n')
  print(confusion_matrix(y_test, y_pred))
  print('\n\nClassification Report :\n')
  print(classification_report(y_test, y_pred))
  print('-' * 55)
  print('\n')
# Out:
# 1. ccwt
#
# Confusion Matrix :
#
# [[12 11]
#  [ 5 17]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.71      0.52      0.60        23
#            1       0.61      0.77      0.68        22
#
#     accuracy                           0.64        45
#    macro avg       0.66      0.65      0.64        45
# weighted avg       0.66      0.64      0.64        45
#
# -------------------------------------------------------
#
#
# 2. mca
#
# Confusion Matrix :
#
# [[11  7]
#  [ 8 13]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.58      0.61      0.59        18
#            1       0.65      0.62      0.63        21
#
#     accuracy                           0.62        39
#    macro avg       0.61      0.62      0.61        39
# weighted avg       0.62      0.62      0.62        39
#
# -------------------------------------------------------
#
#
# 3. java
#
# Confusion Matrix :
#
# [[15  7]
#  [ 2 19]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.68      0.77        22
#            1       0.73      0.90      0.81        21
#
#     accuracy                           0.79        43
#    macro avg       0.81      0.79      0.79        43
# weighted avg       0.81      0.79      0.79        43
#
# -------------------------------------------------------
#
#
# 4. ai
#
# Confusion Matrix :
#
# [[ 7 15]
#  [ 7 10]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.32      0.39        22
#            1       0.40      0.59      0.48        17
#
#     accuracy                           0.44        39
#    macro avg       0.45      0.45      0.43        39
# weighted avg       0.46      0.44      0.43        39
#
# -------------------------------------------------------
#
#
# 5. pslb
#
# Confusion Matrix :
#
# [[ 8  7]
#  [11 12]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.42      0.53      0.47        15
#            1       0.63      0.52      0.57        23
#
#     accuracy                           0.53        38
#    macro avg       0.53      0.53      0.52        38
# weighted avg       0.55      0.53      0.53        38
#
# -------------------------------------------------------
#
#
# 6. np
#
# Confusion Matrix :
#
# [[17 12]
#  [ 4 15]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.59      0.68        29
#            1       0.56      0.79      0.65        19
#
#     accuracy                           0.67        48
#    macro avg       0.68      0.69      0.67        48
# weighted avg       0.71      0.67      0.67        48
#
# -------------------------------------------------------
#
#
# 7. dsa
#
# Confusion Matrix :
#
# [[11  4]
#  [10 16]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.52      0.73      0.61        15
#            1       0.80      0.62      0.70        26
#
#     accuracy                           0.66        41
#    macro avg       0.66      0.67      0.65        41
# weighted avg       0.70      0.66      0.66        41
#
# -------------------------------------------------------
#
#
# 8. os
#
# Confusion Matrix :
#
# [[16  7]
#  [ 3 16]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.70      0.76        23
#            1       0.70      0.84      0.76        19
#
#     accuracy                           0.76        42
#    macro avg       0.77      0.77      0.76        42
# weighted avg       0.78      0.76      0.76        42
#
# -------------------------------------------------------
#
#
# 9. cs
#
# Confusion Matrix :
#
# [[13  9]
#  [ 6 15]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.68      0.59      0.63        22
#            1       0.62      0.71      0.67        21
#
#     accuracy                           0.65        43
#    macro avg       0.65      0.65      0.65        43
# weighted avg       0.66      0.65      0.65        43
#
# -------------------------------------------------------
#
#
# 10. deld
#
# Confusion Matrix :
#
# [[21  4]
#  [ 7 21]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.84      0.79        25
#            1       0.84      0.75      0.79        28
#
#     accuracy                           0.79        53
#    macro avg       0.79      0.79      0.79        53
# weighted avg       0.80      0.79      0.79        53
#
# -------------------------------------------------------
#
#
# 11. cn
#
# Confusion Matrix :
#
# [[ 8 12]
#  [ 6 16]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.40      0.47        20
#            1       0.57      0.73      0.64        22
#
#     accuracy                           0.57        42
#    macro avg       0.57      0.56      0.56        42
# weighted avg       0.57      0.57      0.56        42
#
# -------------------------------------------------------
#
#
# 12. cm
#
# Confusion Matrix :
#
# [[11 11]
#  [ 6 17]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.65      0.50      0.56        22
#            1       0.61      0.74      0.67        23
#
#     accuracy                           0.62        45
#    macro avg       0.63      0.62      0.62        45
# weighted avg       0.63      0.62      0.62        45
#
# -------------------------------------------------------
#
#
# 13. iwt
#
# Confusion Matrix :
#
# [[ 6 25]
#  [ 9  8]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.40      0.19      0.26        31
#            1       0.24      0.47      0.32        17
#
#     accuracy                           0.29        48
#    macro avg       0.32      0.33      0.29        48
# weighted avg       0.34      0.29      0.28        48
#
# -------------------------------------------------------
#
#
# 14. sepm
#
# Confusion Matrix :
#
# [[15 10]
#  [ 5 16]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.60      0.67        25
#            1       0.62      0.76      0.68        21
#
#     accuracy                           0.67        46
#    macro avg       0.68      0.68      0.67        46
# weighted avg       0.69      0.67      0.67        46
#
# -------------------------------------------------------
#
#
# 15. imt
#
# Confusion Matrix :
#
# [[22  7]
#  [ 5 15]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.76      0.79        29
#            1       0.68      0.75      0.71        20
#
#     accuracy                           0.76        49
#    macro avg       0.75      0.75      0.75        49
# weighted avg       0.76      0.76      0.76        49
#
# -------------------------------------------------------
#
#
# 16. dwt
#
# Confusion Matrix :
#
# [[10  4]
#  [ 8 11]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.56      0.71      0.63        14
#            1       0.73      0.58      0.65        19
#
#     accuracy                           0.64        33
#    macro avg       0.64      0.65      0.64        33
# weighted avg       0.66      0.64      0.64        33
#
# -------------------------------------------------------
#
#
# 17. cc
#
# Confusion Matrix :
#
# [[11  9]
#  [ 7 12]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.61      0.55      0.58        20
#            1       0.57      0.63      0.60        19
#
#     accuracy                           0.59        39
#    macro avg       0.59      0.59      0.59        39
# weighted avg       0.59      0.59      0.59        39
#
# -------------------------------------------------------
#
#
# 18. cg
#
# Confusion Matrix :
#
# [[11  8]
#  [ 1 13]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.92      0.58      0.71        19
#            1       0.62      0.93      0.74        14
#
#     accuracy                           0.73        33
#    macro avg       0.77      0.75      0.73        33
# weighted avg       0.79      0.73      0.72        33
#
# -------------------------------------------------------
#
#
# 19. m3
#
# Confusion Matrix :
#
# [[12  6]
#  [ 2 13]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.67      0.75        18
#            1       0.68      0.87      0.76        15
#
#     accuracy                           0.76        33
#    macro avg       0.77      0.77      0.76        33
# weighted avg       0.78      0.76      0.76        33
#
# -------------------------------------------------------
#
#
# 20. crp
#
# Confusion Matrix :
#
# [[14  5]
#  [14 10]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.74      0.60        19
#            1       0.67      0.42      0.51        24
#
#     accuracy                           0.56        43
#    macro avg       0.58      0.58      0.55        43
# weighted avg       0.59      0.56      0.55        43
#
# -------------------------------------------------------
#
#
# 21. csa
#
# Confusion Matrix :
#
# [[ 7  7]
#  [ 5 17]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.58      0.50      0.54        14
#            1       0.71      0.77      0.74        22
#
#     accuracy                           0.67        36
#    macro avg       0.65      0.64      0.64        36
# weighted avg       0.66      0.67      0.66        36
#
# -------------------------------------------------------
#
#
# 22. be
#
# Confusion Matrix :
#
# [[10  5]
#  [ 8 15]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.56      0.67      0.61        15
#            1       0.75      0.65      0.70        23
#
#     accuracy                           0.66        38
#    macro avg       0.65      0.66      0.65        38
# weighted avg       0.67      0.66      0.66        38
#
# -------------------------------------------------------
#
#
# 23. ppc
#
# Confusion Matrix :
#
# [[19  3]
#  [ 7 15]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.86      0.79        22
#            1       0.83      0.68      0.75        22
#
#     accuracy                           0.77        44
#    macro avg       0.78      0.77      0.77        44
# weighted avg       0.78      0.77      0.77        44
#
# -------------------------------------------------------
#
#
# 24. dms
#
# Confusion Matrix :
#
# [[13  7]
#  [ 6 14]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.68      0.65      0.67        20
#            1       0.67      0.70      0.68        20
#
#     accuracy                           0.68        40
#    macro avg       0.68      0.68      0.67        40
# weighted avg       0.68      0.68      0.67        40
#
# -------------------------------------------------------
#
#
# 25. ada
#
# Confusion Matrix :
#
# [[10  8]
#  [ 5 10]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.56      0.61        18
#            1       0.56      0.67      0.61        15
#
#     accuracy                           0.61        33
#    macro avg       0.61      0.61      0.61        33
# weighted avg       0.62      0.61      0.61        33
#
# -------------------------------------------------------
#
#
# 26. mp
#
# Confusion Matrix :
#
# [[14  4]
#  [ 5 13]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.74      0.78      0.76        18
#            1       0.76      0.72      0.74        18
#
#     accuracy                           0.75        36
#    macro avg       0.75      0.75      0.75        36
# weighted avg       0.75      0.75      0.75        36
#
# -------------------------------------------------------

# %% [markdown]
# ### With Random UnderSampling

# %%
for i in range(len(list_of_data_path)):
  data = pd.read_excel(list_of_data_path[i], index_col=0)
  data.replace(-1, 0, inplace = True)
  sub_name = list_of_data_path[i].split('/')[3].split('_')[1].split('.')[0]

  passes = pd.Series(data['ese'] >= 40)
  data = pd.concat([data, passes.rename("Result")], axis=1)

  data.replace({'Result' : {True : 1, False : 0}}, inplace = True)

  X = data[['att','ct1','ct2','ta']]
  y = data['Result']
  rus = RandomUnderSampler(random_state = 12529)
  X_rus, y_rus = rus.fit_resample(X, y)

  X_train, X_test, y_train, y_test = train_test_split(X_rus, y_rus, test_size = 0.3 , random_state = 2529)

  model = LogisticRegression()
  model.fit(X_train, y_train)
  y_pred  = model.predict(X_test)

  temp_dict = classification_report(y_test, y_pred, output_dict=True)
  classification_report_dict['svm_rus'][sub_name + '_model'] = round(temp_dict['accuracy'] * 100, 2)

  print(str(i+1) + '. ' + sub_name)
  print('\nConfusion Matrix :\n')
  print(confusion_matrix(y_test, y_pred))
  print('\n\nClassification Report :\n')
  print(classification_report(y_test, y_pred))
  print('-' * 55)
  print('\n')
# Out:
# 1. ccwt
#
# Confusion Matrix :
#
# [[ 4  3]
#  [ 3 10]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.57      0.57         7
#            1       0.77      0.77      0.77        13
#
#     accuracy                           0.70        20
#    macro avg       0.67      0.67      0.67        20
# weighted avg       0.70      0.70      0.70        20
#
# -------------------------------------------------------
#
#
# 2. mca
#
# Confusion Matrix :
#
# [[6 4]
#  [6 8]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.60      0.55        10
#            1       0.67      0.57      0.62        14
#
#     accuracy                           0.58        24
#    macro avg       0.58      0.59      0.58        24
# weighted avg       0.60      0.58      0.59        24
#
# -------------------------------------------------------
#
#
# 3. java
#
# Confusion Matrix :
#
# [[7 4]
#  [3 8]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.64      0.67        11
#            1       0.67      0.73      0.70        11
#
#     accuracy                           0.68        22
#    macro avg       0.68      0.68      0.68        22
# weighted avg       0.68      0.68      0.68        22
#
# -------------------------------------------------------
#
#
# 4. ai
#
# Confusion Matrix :
#
# [[6 2]
#  [9 4]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.40      0.75      0.52         8
#            1       0.67      0.31      0.42        13
#
#     accuracy                           0.48        21
#    macro avg       0.53      0.53      0.47        21
# weighted avg       0.57      0.48      0.46        21
#
# -------------------------------------------------------
#
#
# 5. pslb
#
# Confusion Matrix :
#
# [[ 8  3]
#  [ 6 10]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.73      0.64        11
#            1       0.77      0.62      0.69        16
#
#     accuracy                           0.67        27
#    macro avg       0.67      0.68      0.66        27
# weighted avg       0.69      0.67      0.67        27
#
# -------------------------------------------------------
#
#
# 6. np
#
# Confusion Matrix :
#
# [[5 3]
#  [1 6]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.62      0.71         8
#            1       0.67      0.86      0.75         7
#
#     accuracy                           0.73        15
#    macro avg       0.75      0.74      0.73        15
# weighted avg       0.76      0.73      0.73        15
#
# -------------------------------------------------------
#
#
# 7. dsa
#
# Confusion Matrix :
#
# [[7 3]
#  [6 8]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.54      0.70      0.61        10
#            1       0.73      0.57      0.64        14
#
#     accuracy                           0.62        24
#    macro avg       0.63      0.64      0.62        24
# weighted avg       0.65      0.62      0.63        24
#
# -------------------------------------------------------
#
#
# 8. os
#
# Confusion Matrix :
#
# [[7 3]
#  [5 8]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.58      0.70      0.64        10
#            1       0.73      0.62      0.67        13
#
#     accuracy                           0.65        23
#    macro avg       0.66      0.66      0.65        23
# weighted avg       0.66      0.65      0.65        23
#
# -------------------------------------------------------
#
#
# 9. cs
#
# Confusion Matrix :
#
# [[6 4]
#  [5 8]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.55      0.60      0.57        10
#            1       0.67      0.62      0.64        13
#
#     accuracy                           0.61        23
#    macro avg       0.61      0.61      0.61        23
# weighted avg       0.61      0.61      0.61        23
#
# -------------------------------------------------------
#
#
# 10. deld
#
# Confusion Matrix :
#
# [[4 3]
#  [1 5]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.57      0.67         7
#            1       0.62      0.83      0.71         6
#
#     accuracy                           0.69        13
#    macro avg       0.71      0.70      0.69        13
# weighted avg       0.72      0.69      0.69        13
#
# -------------------------------------------------------
#
#
# 11. cn
#
# Confusion Matrix :
#
# [[6 4]
#  [6 7]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.60      0.55        10
#            1       0.64      0.54      0.58        13
#
#     accuracy                           0.57        23
#    macro avg       0.57      0.57      0.56        23
# weighted avg       0.58      0.57      0.57        23
#
# -------------------------------------------------------
#
#
# 12. cm
#
# Confusion Matrix :
#
# [[4 4]
#  [4 9]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.50      0.50         8
#            1       0.69      0.69      0.69        13
#
#     accuracy                           0.62        21
#    macro avg       0.60      0.60      0.60        21
# weighted avg       0.62      0.62      0.62        21
#
# -------------------------------------------------------
#
#
# 13. iwt
#
# Confusion Matrix :
#
# [[2 6]
#  [2 2]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.25      0.33         8
#            1       0.25      0.50      0.33         4
#
#     accuracy                           0.33        12
#    macro avg       0.38      0.38      0.33        12
# weighted avg       0.42      0.33      0.33        12
#
# -------------------------------------------------------
#
#
# 14. sepm
#
# Confusion Matrix :
#
# [[4 4]
#  [5 6]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.44      0.50      0.47         8
#            1       0.60      0.55      0.57        11
#
#     accuracy                           0.53        19
#    macro avg       0.52      0.52      0.52        19
# weighted avg       0.53      0.53      0.53        19
#
# -------------------------------------------------------
#
#
# 15. imt
#
# Confusion Matrix :
#
# [[0 5]
#  [4 2]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         5
#            1       0.29      0.33      0.31         6
#
#     accuracy                           0.18        11
#    macro avg       0.14      0.17      0.15        11
# weighted avg       0.16      0.18      0.17        11
#
# -------------------------------------------------------
#
#
# 16. dwt
#
# Confusion Matrix :
#
# [[7 4]
#  [7 9]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.64      0.56        11
#            1       0.69      0.56      0.62        16
#
#     accuracy                           0.59        27
#    macro avg       0.60      0.60      0.59        27
# weighted avg       0.61      0.59      0.60        27
#
# -------------------------------------------------------
#
#
# 17. cc
#
# Confusion Matrix :
#
# [[6 4]
#  [9 5]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.40      0.60      0.48        10
#            1       0.56      0.36      0.43        14
#
#     accuracy                           0.46        24
#    macro avg       0.48      0.48      0.46        24
# weighted avg       0.49      0.46      0.45        24
#
# -------------------------------------------------------
#
#
# 18. cg
#
# Confusion Matrix :
#
# [[ 5  9]
#  [ 4 14]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.56      0.36      0.43        14
#            1       0.61      0.78      0.68        18
#
#     accuracy                           0.59        32
#    macro avg       0.58      0.57      0.56        32
# weighted avg       0.59      0.59      0.57        32
#
# -------------------------------------------------------
#
#
# 19. m3
#
# Confusion Matrix :
#
# [[12  6]
#  [ 3 11]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73        18
#            1       0.65      0.79      0.71        14
#
#     accuracy                           0.72        32
#    macro avg       0.72      0.73      0.72        32
# weighted avg       0.73      0.72      0.72        32
#
# -------------------------------------------------------
#
#
# 20. crp
#
# Confusion Matrix :
#
# [[8 0]
#  [7 6]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.53      1.00      0.70         8
#            1       1.00      0.46      0.63        13
#
#     accuracy                           0.67        21
#    macro avg       0.77      0.73      0.66        21
# weighted avg       0.82      0.67      0.66        21
#
# -------------------------------------------------------
#
#
# 21. csa
#
# Confusion Matrix :
#
# [[ 5  7]
#  [ 4 13]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.56      0.42      0.48        12
#            1       0.65      0.76      0.70        17
#
#     accuracy                           0.62        29
#    macro avg       0.60      0.59      0.59        29
# weighted avg       0.61      0.62      0.61        29
#
# -------------------------------------------------------
#
#
# 22. be
#
# Confusion Matrix :
#
# [[10  1]
#  [ 8  8]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.56      0.91      0.69        11
#            1       0.89      0.50      0.64        16
#
#     accuracy                           0.67        27
#    macro avg       0.72      0.70      0.66        27
# weighted avg       0.75      0.67      0.66        27
#
# -------------------------------------------------------
#
#
# 23. ppc
#
# Confusion Matrix :
#
# [[6 1]
#  [9 4]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.40      0.86      0.55         7
#            1       0.80      0.31      0.44        13
#
#     accuracy                           0.50        20
#    macro avg       0.60      0.58      0.49        20
# weighted avg       0.66      0.50      0.48        20
#
# -------------------------------------------------------
#
#
# 24. dms
#
# Confusion Matrix :
#
# [[7 4]
#  [6 8]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.54      0.64      0.58        11
#            1       0.67      0.57      0.62        14
#
#     accuracy                           0.60        25
#    macro avg       0.60      0.60      0.60        25
# weighted avg       0.61      0.60      0.60        25
#
# -------------------------------------------------------
#
#
# 25. ada
#
# Confusion Matrix :
#
# [[10  8]
#  [ 5  9]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.56      0.61        18
#            1       0.53      0.64      0.58        14
#
#     accuracy                           0.59        32
#    macro avg       0.60      0.60      0.59        32
# weighted avg       0.61      0.59      0.59        32
#
# -------------------------------------------------------
#
#
# 26. mp
#
# Confusion Matrix :
#
# [[ 9  3]
#  [ 3 14]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.75      0.75        12
#            1       0.82      0.82      0.82        17
#
#     accuracy                           0.79        29
#    macro avg       0.79      0.79      0.79        29
# weighted avg       0.79      0.79      0.79        29
#
# -------------------------------------------------------

# %% [markdown]
# ## XGB Classifier

# %% [markdown]
# ### With No Further Processing

# %%
for i in range(len(list_of_data_path)):
  data = pd.read_excel(list_of_data_path[i], index_col=0)
  data.replace(-1, 0, inplace = True)
  sub_name = list_of_data_path[i].split('/')[3].split('_')[1].split('.')[0]

  passes = pd.Series(data['ese'] >= 40)
  data = pd.concat([data, passes.rename("Result")], axis=1)

  data.replace({'Result' : {True : 1, False : 0}}, inplace = True)

  X = data[['att','ct1','ct2','ta']]
  y = data['Result']
  X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.3 , random_state = 2529)

  model = xgb.XGBClassifier()
  model.fit(X_train, y_train)
  y_pred  = model.predict(X_test)

  temp_dict = classification_report(y_test, y_pred, output_dict=True)
  classification_report_dict['xgb_nfp'][sub_name + '_model'] = round(temp_dict['accuracy'] * 100, 2)

  print(str(i+1) + '. ' + sub_name)
  print('\nConfusion Matrix :\n')
  print(confusion_matrix(y_test, y_pred))
  print('\n\nClassification Report :\n')
  print(classification_report(y_test, y_pred))
  print('-' * 55)
  print('\n')
# Out:
# 1. ccwt
#
# Confusion Matrix :
#
# [[ 5  3]
#  [ 4 21]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.56      0.62      0.59         8
#            1       0.88      0.84      0.86        25
#
#     accuracy                           0.79        33
#    macro avg       0.72      0.73      0.72        33
# weighted avg       0.80      0.79      0.79        33
#
# -------------------------------------------------------
#
#
# 2. mca
#
# Confusion Matrix :
#
# [[ 5  4]
#  [ 3 20]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.56      0.59         9
#            1       0.83      0.87      0.85        23
#
#     accuracy                           0.78        32
#    macro avg       0.73      0.71      0.72        32
# weighted avg       0.77      0.78      0.78        32
#
# -------------------------------------------------------
#
#
# 3. java
#
# Confusion Matrix :
#
# [[ 5  6]
#  [ 2 20]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.71      0.45      0.56        11
#            1       0.77      0.91      0.83        22
#
#     accuracy                           0.76        33
#    macro avg       0.74      0.68      0.69        33
# weighted avg       0.75      0.76      0.74        33
#
# -------------------------------------------------------
#
#
# 4. ai
#
# Confusion Matrix :
#
# [[ 1  9]
#  [ 7 13]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.12      0.10      0.11        10
#            1       0.59      0.65      0.62        20
#
#     accuracy                           0.47        30
#    macro avg       0.36      0.38      0.37        30
# weighted avg       0.44      0.47      0.45        30
#
# -------------------------------------------------------
#
#
# 5. pslb
#
# Confusion Matrix :
#
# [[15  3]
#  [ 8  7]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.65      0.83      0.73        18
#            1       0.70      0.47      0.56        15
#
#     accuracy                           0.67        33
#    macro avg       0.68      0.65      0.65        33
# weighted avg       0.67      0.67      0.65        33
#
# -------------------------------------------------------
#
#
# 6. np
#
# Confusion Matrix :
#
# [[ 3  2]
#  [ 3 24]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.60      0.55         5
#            1       0.92      0.89      0.91        27
#
#     accuracy                           0.84        32
#    macro avg       0.71      0.74      0.73        32
# weighted avg       0.86      0.84      0.85        32
#
# -------------------------------------------------------
#
#
# 7. dsa
#
# Confusion Matrix :
#
# [[ 5  8]
#  [ 5 15]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.38      0.43        13
#            1       0.65      0.75      0.70        20
#
#     accuracy                           0.61        33
#    macro avg       0.58      0.57      0.57        33
# weighted avg       0.59      0.61      0.59        33
#
# -------------------------------------------------------
#
#
# 8. os
#
# Confusion Matrix :
#
# [[ 6  7]
#  [ 5 15]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.55      0.46      0.50        13
#            1       0.68      0.75      0.71        20
#
#     accuracy                           0.64        33
#    macro avg       0.61      0.61      0.61        33
# weighted avg       0.63      0.64      0.63        33
#
# -------------------------------------------------------
#
#
# 9. cs
#
# Confusion Matrix :
#
# [[22  2]
#  [ 3  6]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.92      0.90        24
#            1       0.75      0.67      0.71         9
#
#     accuracy                           0.85        33
#    macro avg       0.81      0.79      0.80        33
# weighted avg       0.84      0.85      0.85        33
#
# -------------------------------------------------------
#
#
# 10. deld
#
# Confusion Matrix :
#
# [[22  3]
#  [ 6  2]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.79      0.88      0.83        25
#            1       0.40      0.25      0.31         8
#
#     accuracy                           0.73        33
#    macro avg       0.59      0.56      0.57        33
# weighted avg       0.69      0.73      0.70        33
#
# -------------------------------------------------------
#
#
# 11. cn
#
# Confusion Matrix :
#
# [[18  5]
#  [ 3  7]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.78      0.82        23
#            1       0.58      0.70      0.64        10
#
#     accuracy                           0.76        33
#    macro avg       0.72      0.74      0.73        33
# weighted avg       0.77      0.76      0.76        33
#
# -------------------------------------------------------
#
#
# 12. cm
#
# Confusion Matrix :
#
# [[ 4  8]
#  [ 6 15]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.40      0.33      0.36        12
#            1       0.65      0.71      0.68        21
#
#     accuracy                           0.58        33
#    macro avg       0.53      0.52      0.52        33
# weighted avg       0.56      0.58      0.57        33
#
# -------------------------------------------------------
#
#
# 13. iwt
#
# Confusion Matrix :
#
# [[ 0  7]
#  [ 3 20]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         7
#            1       0.74      0.87      0.80        23
#
#     accuracy                           0.67        30
#    macro avg       0.37      0.43      0.40        30
# weighted avg       0.57      0.67      0.61        30
#
# -------------------------------------------------------
#
#
# 14. sepm
#
# Confusion Matrix :
#
# [[ 6  4]
#  [ 1 22]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.60      0.71        10
#            1       0.85      0.96      0.90        23
#
#     accuracy                           0.85        33
#    macro avg       0.85      0.78      0.80        33
# weighted avg       0.85      0.85      0.84        33
#
# -------------------------------------------------------
#
#
# 15. imt
#
# Confusion Matrix :
#
# [[ 0  7]
#  [ 0 23]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         7
#            1       0.77      1.00      0.87        23
#
#     accuracy                           0.77        30
#    macro avg       0.38      0.50      0.43        30
# weighted avg       0.59      0.77      0.67        30
#
# -------------------------------------------------------
#
#
# 16. dwt
#
# Confusion Matrix :
#
# [[10  5]
#  [ 5 10]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.67      0.67        15
#            1       0.67      0.67      0.67        15
#
#     accuracy                           0.67        30
#    macro avg       0.67      0.67      0.67        30
# weighted avg       0.67      0.67      0.67        30
#
# -------------------------------------------------------
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 17. cc
#
# Confusion Matrix :
#
# [[ 3  9]
#  [ 8 12]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.27      0.25      0.26        12
#            1       0.57      0.60      0.59        20
#
#     accuracy                           0.47        32
#    macro avg       0.42      0.42      0.42        32
# weighted avg       0.46      0.47      0.46        32
#
# -------------------------------------------------------
#
#
# 18. cg
#
# Confusion Matrix :
#
# [[12  8]
#  [ 4  9]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.60      0.67        20
#            1       0.53      0.69      0.60        13
#
#     accuracy                           0.64        33
#    macro avg       0.64      0.65      0.63        33
# weighted avg       0.66      0.64      0.64        33
#
# -------------------------------------------------------
#
#
# 19. m3
#
# Confusion Matrix :
#
# [[ 9  7]
#  [ 4 13]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.69      0.56      0.62        16
#            1       0.65      0.76      0.70        17
#
#     accuracy                           0.67        33
#    macro avg       0.67      0.66      0.66        33
# weighted avg       0.67      0.67      0.66        33
#
# -------------------------------------------------------
#
#
# 20. crp
#
# Confusion Matrix :
#
# [[ 4  5]
#  [ 5 18]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.44      0.44      0.44         9
#            1       0.78      0.78      0.78        23
#
#     accuracy                           0.69        32
#    macro avg       0.61      0.61      0.61        32
# weighted avg       0.69      0.69      0.69        32
#
# -------------------------------------------------------
#
#
# 21. csa
#
# Confusion Matrix :
#
# [[12  6]
#  [ 6  9]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.67      0.67        18
#            1       0.60      0.60      0.60        15
#
#     accuracy                           0.64        33
#    macro avg       0.63      0.63      0.63        33
# weighted avg       0.64      0.64      0.64        33
#
# -------------------------------------------------------
#
#
# 22. be
#
# Confusion Matrix :
#
# [[14  2]
#  [ 6 11]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.88      0.78        16
#            1       0.85      0.65      0.73        17
#
#     accuracy                           0.76        33
#    macro avg       0.77      0.76      0.76        33
# weighted avg       0.78      0.76      0.75        33
#
# -------------------------------------------------------
#
#
# 23. ppc
#
# Confusion Matrix :
#
# [[ 6  5]
#  [ 2 19]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.55      0.63        11
#            1       0.79      0.90      0.84        21
#
#     accuracy                           0.78        32
#    macro avg       0.77      0.73      0.74        32
# weighted avg       0.78      0.78      0.77        32
#
# -------------------------------------------------------
#
#
# 24. dms
#
# Confusion Matrix :
#
# [[17  4]
#  [ 6  6]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.74      0.81      0.77        21
#            1       0.60      0.50      0.55        12
#
#     accuracy                           0.70        33
#    macro avg       0.67      0.65      0.66        33
# weighted avg       0.69      0.70      0.69        33
#
# -------------------------------------------------------
#
#
# 25. ada
#
# Confusion Matrix :
#
# [[11  4]
#  [ 8 10]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.58      0.73      0.65        15
#            1       0.71      0.56      0.63        18
#
#     accuracy                           0.64        33
#    macro avg       0.65      0.64      0.64        33
# weighted avg       0.65      0.64      0.64        33
#
# -------------------------------------------------------
#
#
# 26. mp
#
# Confusion Matrix :
#
# [[14  5]
#  [ 3 11]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.82      0.74      0.78        19
#            1       0.69      0.79      0.73        14
#
#     accuracy                           0.76        33
#    macro avg       0.76      0.76      0.76        33
# weighted avg       0.77      0.76      0.76        33
#
# -------------------------------------------------------

# %% [markdown]
# ### With Random OverSampling

# %%
for i in range(len(list_of_data_path)):
  data = pd.read_excel(list_of_data_path[i], index_col=0)
  data.replace(-1, 0, inplace = True)
  sub_name = list_of_data_path[i].split('/')[3].split('_')[1].split('.')[0]

  passes = pd.Series(data['ese'] >= 40)
  data = pd.concat([data, passes.rename("Result")], axis=1)

  data.replace({'Result' : {True : 1, False : 0}}, inplace = True)

  X = data[['att','ct1','ct2','ta']]
  y = data['Result']
  ros = RandomOverSampler(random_state = 12529)
  X_ros, y_ros = ros.fit_resample(X, y)

  X_train, X_test, y_train, y_test = train_test_split(X_ros, y_ros, test_size = 0.3 , random_state = 2529)

  model = xgb.XGBClassifier()
  model.fit(X_train, y_train)

  joblib.dump(model, '/content/models/' + sub_name + '_model.pkl')

  y_pred  = model.predict(X_test)

  temp_dict = classification_report(y_test, y_pred, output_dict=True)
  classification_report_dict['xgb_ros'][sub_name + '_model'] = round(temp_dict['accuracy'] * 100, 2)

  print(str(i+1) + '. ' + sub_name)
  print('\nConfusion Matrix :\n')
  print(confusion_matrix(y_test, y_pred))
  print('\n\nClassification Report :\n')
  print(classification_report(y_test, y_pred))
  print('-' * 55)
  print('\n')
# Out:
# 1. ccwt
#
# Confusion Matrix :
#
# [[19  4]
#  [ 6 16]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.76      0.83      0.79        23
#            1       0.80      0.73      0.76        22
#
#     accuracy                           0.78        45
#    macro avg       0.78      0.78      0.78        45
# weighted avg       0.78      0.78      0.78        45
#
# -------------------------------------------------------
#
#
# 2. mca
#
# Confusion Matrix :
#
# [[13  5]
#  [ 4 17]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.76      0.72      0.74        18
#            1       0.77      0.81      0.79        21
#
#     accuracy                           0.77        39
#    macro avg       0.77      0.77      0.77        39
# weighted avg       0.77      0.77      0.77        39
#
# -------------------------------------------------------
#
#
# 3. java
#
# Confusion Matrix :
#
# [[17  5]
#  [ 4 17]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.77      0.79        22
#            1       0.77      0.81      0.79        21
#
#     accuracy                           0.79        43
#    macro avg       0.79      0.79      0.79        43
# weighted avg       0.79      0.79      0.79        43
#
# -------------------------------------------------------
#
#
# 4. ai
#
# Confusion Matrix :
#
# [[13  9]
#  [ 4 13]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.76      0.59      0.67        22
#            1       0.59      0.76      0.67        17
#
#     accuracy                           0.67        39
#    macro avg       0.68      0.68      0.67        39
# weighted avg       0.69      0.67      0.67        39
#
# -------------------------------------------------------
#
#
# 5. pslb
#
# Confusion Matrix :
#
# [[ 7  8]
#  [ 7 16]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.47      0.48        15
#            1       0.67      0.70      0.68        23
#
#     accuracy                           0.61        38
#    macro avg       0.58      0.58      0.58        38
# weighted avg       0.60      0.61      0.60        38
#
# -------------------------------------------------------
#
#
# 6. np
#
# Confusion Matrix :
#
# [[26  3]
#  [ 2 17]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.93      0.90      0.91        29
#            1       0.85      0.89      0.87        19
#
#     accuracy                           0.90        48
#    macro avg       0.89      0.90      0.89        48
# weighted avg       0.90      0.90      0.90        48
#
# -------------------------------------------------------
#
#
# 7. dsa
#
# Confusion Matrix :
#
# [[12  3]
#  [ 9 17]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.80      0.67        15
#            1       0.85      0.65      0.74        26
#
#     accuracy                           0.71        41
#    macro avg       0.71      0.73      0.70        41
# weighted avg       0.75      0.71      0.71        41
#
# -------------------------------------------------------
#
#
# 8. os
#
# Confusion Matrix :
#
# [[18  5]
#  [ 5 14]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.78      0.78      0.78        23
#            1       0.74      0.74      0.74        19
#
#     accuracy                           0.76        42
#    macro avg       0.76      0.76      0.76        42
# weighted avg       0.76      0.76      0.76        42
#
# -------------------------------------------------------
#
#
# 9. cs
#
# Confusion Matrix :
#
# [[16  6]
#  [ 7 14]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.73      0.71        22
#            1       0.70      0.67      0.68        21
#
#     accuracy                           0.70        43
#    macro avg       0.70      0.70      0.70        43
# weighted avg       0.70      0.70      0.70        43
#
# -------------------------------------------------------
#
#
# 10. deld
#
# Confusion Matrix :
#
# [[21  4]
#  [ 0 28]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.84      0.91        25
#            1       0.88      1.00      0.93        28
#
#     accuracy                           0.92        53
#    macro avg       0.94      0.92      0.92        53
# weighted avg       0.93      0.92      0.92        53
#
# -------------------------------------------------------
#
#
# 11. cn
#
# Confusion Matrix :
#
# [[12  8]
#  [ 6 16]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.60      0.63        20
#            1       0.67      0.73      0.70        22
#
#     accuracy                           0.67        42
#    macro avg       0.67      0.66      0.66        42
# weighted avg       0.67      0.67      0.67        42
#
# -------------------------------------------------------
#
#
# 12. cm
#
# Confusion Matrix :
#
# [[17  5]
#  [ 9 14]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.65      0.77      0.71        22
#            1       0.74      0.61      0.67        23
#
#     accuracy                           0.69        45
#    macro avg       0.70      0.69      0.69        45
# weighted avg       0.70      0.69      0.69        45
#
# -------------------------------------------------------
#
#
# 13. iwt
#
# Confusion Matrix :
#
# [[21 10]
#  [ 7 10]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.68      0.71        31
#            1       0.50      0.59      0.54        17
#
#     accuracy                           0.65        48
#    macro avg       0.62      0.63      0.63        48
# weighted avg       0.66      0.65      0.65        48
#
# -------------------------------------------------------
#
#
# 14. sepm
#
# Confusion Matrix :
#
# [[20  5]
#  [ 5 16]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80        25
#            1       0.76      0.76      0.76        21
#
#     accuracy                           0.78        46
#    macro avg       0.78      0.78      0.78        46
# weighted avg       0.78      0.78      0.78        46
#
# -------------------------------------------------------
#
#
# 15. imt
#
# Confusion Matrix :
#
# [[23  6]
#  [ 6 14]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.79      0.79      0.79        29
#            1       0.70      0.70      0.70        20
#
#     accuracy                           0.76        49
#    macro avg       0.75      0.75      0.75        49
# weighted avg       0.76      0.76      0.76        49
#
# -------------------------------------------------------
#
#
# 16. dwt
#
# Confusion Matrix :
#
# [[11  3]
#  [11  8]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.79      0.61        14
#            1       0.73      0.42      0.53        19
#
#     accuracy                           0.58        33
#    macro avg       0.61      0.60      0.57        33
# weighted avg       0.63      0.58      0.57        33
#
# -------------------------------------------------------
#
#
# 17. cc
#
# Confusion Matrix :
#
# [[12  8]
#  [ 8 11]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.60      0.60      0.60        20
#            1       0.58      0.58      0.58        19
#
#     accuracy                           0.59        39
#    macro avg       0.59      0.59      0.59        39
# weighted avg       0.59      0.59      0.59        39
#
# -------------------------------------------------------
#
#
# 18. cg
#
# Confusion Matrix :
#
# [[11  8]
#  [ 5  9]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.69      0.58      0.63        19
#            1       0.53      0.64      0.58        14
#
#     accuracy                           0.61        33
#    macro avg       0.61      0.61      0.60        33
# weighted avg       0.62      0.61      0.61        33
#
# -------------------------------------------------------
#
#
# 19. m3
#
# Confusion Matrix :
#
# [[13  5]
#  [ 3 12]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.72      0.76        18
#            1       0.71      0.80      0.75        15
#
#     accuracy                           0.76        33
#    macro avg       0.76      0.76      0.76        33
# weighted avg       0.76      0.76      0.76        33
#
# -------------------------------------------------------
#
#
# 20. crp
#
# Confusion Matrix :
#
# [[14  5]
#  [11 13]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.56      0.74      0.64        19
#            1       0.72      0.54      0.62        24
#
#     accuracy                           0.63        43
#    macro avg       0.64      0.64      0.63        43
# weighted avg       0.65      0.63      0.63        43
#
# -------------------------------------------------------
#
#
# 21. csa
#
# Confusion Matrix :
#
# [[ 6  8]
#  [ 3 19]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.43      0.52        14
#            1       0.70      0.86      0.78        22
#
#     accuracy                           0.69        36
#    macro avg       0.69      0.65      0.65        36
# weighted avg       0.69      0.69      0.68        36
#
# -------------------------------------------------------
#
#
# 22. be
#
# Confusion Matrix :
#
# [[11  4]
#  [ 7 16]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.61      0.73      0.67        15
#            1       0.80      0.70      0.74        23
#
#     accuracy                           0.71        38
#    macro avg       0.71      0.71      0.71        38
# weighted avg       0.73      0.71      0.71        38
#
# -------------------------------------------------------
#
#
# 23. ppc
#
# Confusion Matrix :
#
# [[20  2]
#  [ 8 14]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.71      0.91      0.80        22
#            1       0.88      0.64      0.74        22
#
#     accuracy                           0.77        44
#    macro avg       0.79      0.77      0.77        44
# weighted avg       0.79      0.77      0.77        44
#
# -------------------------------------------------------
#
#
# 24. dms
#
# Confusion Matrix :
#
# [[13  7]
#  [ 7 13]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.65      0.65      0.65        20
#            1       0.65      0.65      0.65        20
#
#     accuracy                           0.65        40
#    macro avg       0.65      0.65      0.65        40
# weighted avg       0.65      0.65      0.65        40
#
# -------------------------------------------------------
#
#
# 25. ada
#
# Confusion Matrix :
#
# [[9 9]
#  [8 7]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.53      0.50      0.51        18
#            1       0.44      0.47      0.45        15
#
#     accuracy                           0.48        33
#    macro avg       0.48      0.48      0.48        33
# weighted avg       0.49      0.48      0.49        33
#
# -------------------------------------------------------
#
#
# 26. mp
#
# Confusion Matrix :
#
# [[13  5]
#  [ 5 13]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.72      0.72      0.72        18
#            1       0.72      0.72      0.72        18
#
#     accuracy                           0.72        36
#    macro avg       0.72      0.72      0.72        36
# weighted avg       0.72      0.72      0.72        36
#
# -------------------------------------------------------

# %% [markdown]
# ### With Random UnderSampling

# %%
for i in range(len(list_of_data_path)):
  data = pd.read_excel(list_of_data_path[i], index_col=0)
  data.replace(-1, 0, inplace = True)
  sub_name = list_of_data_path[i].split('/')[3].split('_')[1].split('.')[0]

  passes = pd.Series(data['ese'] >= 40)
  data = pd.concat([data, passes.rename("Result")], axis=1)

  data.replace({'Result' : {True : 1, False : 0}}, inplace = True)

  X = data[['att','ct1','ct2','ta']]
  y = data['Result']
  rus = RandomUnderSampler(random_state = 12529)
  X_rus, y_rus = rus.fit_resample(X, y)

  X_train, X_test, y_train, y_test = train_test_split(X_rus, y_rus, test_size = 0.3 , random_state = 2529)

  model = xgb.XGBClassifier()
  model.fit(X_train, y_train)
  y_pred  = model.predict(X_test)

  temp_dict = classification_report(y_test, y_pred, output_dict=True)
  classification_report_dict['xgb_rus'][sub_name + '_model'] = round(temp_dict['accuracy'] * 100, 2)

  print(str(i+1) + '. ' + sub_name)
  print('\nConfusion Matrix :\n')
  print(confusion_matrix(y_test, y_pred))
  print('\n\nClassification Report :\n')
  print(classification_report(y_test, y_pred))
  print('-' * 55)
  print('\n')
# Out:
# 1. ccwt
#
# Confusion Matrix :
#
# [[ 4  3]
#  [ 3 10]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.57      0.57         7
#            1       0.77      0.77      0.77        13
#
#     accuracy                           0.70        20
#    macro avg       0.67      0.67      0.67        20
# weighted avg       0.70      0.70      0.70        20
#
# -------------------------------------------------------
#
#
# 2. mca
#
# Confusion Matrix :
#
# [[ 4  6]
#  [ 3 11]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.40      0.47        10
#            1       0.65      0.79      0.71        14
#
#     accuracy                           0.62        24
#    macro avg       0.61      0.59      0.59        24
# weighted avg       0.62      0.62      0.61        24
#
# -------------------------------------------------------
#
#
# 3. java
#
# Confusion Matrix :
#
# [[ 5  6]
#  [ 1 10]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.45      0.59        11
#            1       0.62      0.91      0.74        11
#
#     accuracy                           0.68        22
#    macro avg       0.73      0.68      0.66        22
# weighted avg       0.73      0.68      0.66        22
#
# -------------------------------------------------------
#
#
# 4. ai
#
# Confusion Matrix :
#
# [[3 5]
#  [8 5]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.27      0.38      0.32         8
#            1       0.50      0.38      0.43        13
#
#     accuracy                           0.38        21
#    macro avg       0.39      0.38      0.38        21
# weighted avg       0.41      0.38      0.39        21
#
# -------------------------------------------------------
#
#
# 5. pslb
#
# Confusion Matrix :
#
# [[9 2]
#  [8 8]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.53      0.82      0.64        11
#            1       0.80      0.50      0.62        16
#
#     accuracy                           0.63        27
#    macro avg       0.66      0.66      0.63        27
# weighted avg       0.69      0.63      0.63        27
#
# -------------------------------------------------------
#
#
# 6. np
#
# Confusion Matrix :
#
# [[6 2]
#  [1 6]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.75      0.80         8
#            1       0.75      0.86      0.80         7
#
#     accuracy                           0.80        15
#    macro avg       0.80      0.80      0.80        15
# weighted avg       0.81      0.80      0.80        15
#
# -------------------------------------------------------
#
#
# 7. dsa
#
# Confusion Matrix :
#
# [[7 3]
#  [5 9]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.58      0.70      0.64        10
#            1       0.75      0.64      0.69        14
#
#     accuracy                           0.67        24
#    macro avg       0.67      0.67      0.66        24
# weighted avg       0.68      0.67      0.67        24
#
# -------------------------------------------------------
#
#
# 8. os
#
# Confusion Matrix :
#
# [[4 6]
#  [6 7]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.40      0.40      0.40        10
#            1       0.54      0.54      0.54        13
#
#     accuracy                           0.48        23
#    macro avg       0.47      0.47      0.47        23
# weighted avg       0.48      0.48      0.48        23
#
# -------------------------------------------------------
#
#
# 9. cs
#
# Confusion Matrix :
#
# [[ 6  4]
#  [ 3 10]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.60      0.63        10
#            1       0.71      0.77      0.74        13
#
#     accuracy                           0.70        23
#    macro avg       0.69      0.68      0.69        23
# weighted avg       0.69      0.70      0.69        23
#
# -------------------------------------------------------
#
#
# 10. deld
#
# Confusion Matrix :
#
# [[5 2]
#  [1 5]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.71      0.77         7
#            1       0.71      0.83      0.77         6
#
#     accuracy                           0.77        13
#    macro avg       0.77      0.77      0.77        13
# weighted avg       0.78      0.77      0.77        13
#
# -------------------------------------------------------
#
#
# 11. cn
#
# Confusion Matrix :
#
# [[5 5]
#  [5 8]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.50      0.50        10
#            1       0.62      0.62      0.62        13
#
#     accuracy                           0.57        23
#    macro avg       0.56      0.56      0.56        23
# weighted avg       0.57      0.57      0.57        23
#
# -------------------------------------------------------
#
#
# 12. cm
#
# Confusion Matrix :
#
# [[2 6]
#  [5 8]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.29      0.25      0.27         8
#            1       0.57      0.62      0.59        13
#
#     accuracy                           0.48        21
#    macro avg       0.43      0.43      0.43        21
# weighted avg       0.46      0.48      0.47        21
#
# -------------------------------------------------------
#
#
# 13. iwt
#
# Confusion Matrix :
#
# [[3 5]
#  [2 2]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.60      0.38      0.46         8
#            1       0.29      0.50      0.36         4
#
#     accuracy                           0.42        12
#    macro avg       0.44      0.44      0.41        12
# weighted avg       0.50      0.42      0.43        12
#
# -------------------------------------------------------
#
#
# 14. sepm
#
# Confusion Matrix :
#
# [[4 4]
#  [5 6]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.44      0.50      0.47         8
#            1       0.60      0.55      0.57        11
#
#     accuracy                           0.53        19
#    macro avg       0.52      0.52      0.52        19
# weighted avg       0.53      0.53      0.53        19
#
# -------------------------------------------------------
#
#
# 15. imt
#
# Confusion Matrix :
#
# [[0 5]
#  [4 2]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         5
#            1       0.29      0.33      0.31         6
#
#     accuracy                           0.18        11
#    macro avg       0.14      0.17      0.15        11
# weighted avg       0.16      0.18      0.17        11
#
# -------------------------------------------------------
#
#
# 16. dwt
#
# Confusion Matrix :
#
# [[8 3]
#  [8 8]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.73      0.59        11
#            1       0.73      0.50      0.59        16
#
#     accuracy                           0.59        27
#    macro avg       0.61      0.61      0.59        27
# weighted avg       0.63      0.59      0.59        27
#
# -------------------------------------------------------
#
#
# 17. cc
#
# Confusion Matrix :
#
# [[5 5]
#  [9 5]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.36      0.50      0.42        10
#            1       0.50      0.36      0.42        14
#
#     accuracy                           0.42        24
#    macro avg       0.43      0.43      0.42        24
# weighted avg       0.44      0.42      0.42        24
#
# -------------------------------------------------------
#
#
# 18. cg
#
# Confusion Matrix :
#
# [[ 4 10]
#  [ 9  9]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.31      0.29      0.30        14
#            1       0.47      0.50      0.49        18
#
#     accuracy                           0.41        32
#    macro avg       0.39      0.39      0.39        32
# weighted avg       0.40      0.41      0.40        32
#
# -------------------------------------------------------
#
#
# 19. m3
#
# Confusion Matrix :
#
# [[9 9]
#  [6 8]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.60      0.50      0.55        18
#            1       0.47      0.57      0.52        14
#
#     accuracy                           0.53        32
#    macro avg       0.54      0.54      0.53        32
# weighted avg       0.54      0.53      0.53        32
#
# -------------------------------------------------------
#
#
# 20. crp
#
# Confusion Matrix :
#
# [[6 2]
#  [7 6]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.46      0.75      0.57         8
#            1       0.75      0.46      0.57        13
#
#     accuracy                           0.57        21
#    macro avg       0.61      0.61      0.57        21
# weighted avg       0.64      0.57      0.57        21
#
# -------------------------------------------------------
#
#
# 21. csa
#
# Confusion Matrix :
#
# [[ 5  7]
#  [ 5 12]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.42      0.45        12
#            1       0.63      0.71      0.67        17
#
#     accuracy                           0.59        29
#    macro avg       0.57      0.56      0.56        29
# weighted avg       0.58      0.59      0.58        29
#
# -------------------------------------------------------
#
#
# 22. be
#
# Confusion Matrix :
#
# [[10  1]
#  [ 5 11]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.91      0.77        11
#            1       0.92      0.69      0.79        16
#
#     accuracy                           0.78        27
#    macro avg       0.79      0.80      0.78        27
# weighted avg       0.81      0.78      0.78        27
#
# -------------------------------------------------------
#
#
# 23. ppc
#
# Confusion Matrix :
#
# [[6 1]
#  [7 6]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.46      0.86      0.60         7
#            1       0.86      0.46      0.60        13
#
#     accuracy                           0.60        20
#    macro avg       0.66      0.66      0.60        20
# weighted avg       0.72      0.60      0.60        20
#
# -------------------------------------------------------
#
#
# 24. dms
#
# Confusion Matrix :
#
# [[ 9  2]
#  [11  3]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.45      0.82      0.58        11
#            1       0.60      0.21      0.32        14
#
#     accuracy                           0.48        25
#    macro avg       0.53      0.52      0.45        25
# weighted avg       0.53      0.48      0.43        25
#
# -------------------------------------------------------
#
#
# 25. ada
#
# Confusion Matrix :
#
# [[14  4]
#  [ 6  8]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.78      0.74        18
#            1       0.67      0.57      0.62        14
#
#     accuracy                           0.69        32
#    macro avg       0.68      0.67      0.68        32
# weighted avg       0.69      0.69      0.68        32
#
# -------------------------------------------------------
#
#
# 26. mp
#
# Confusion Matrix :
#
# [[ 8  4]
#  [ 7 10]]
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.53      0.67      0.59        12
#            1       0.71      0.59      0.65        17
#
#     accuracy                           0.62        29
#    macro avg       0.62      0.63      0.62        29
# weighted avg       0.64      0.62      0.62        29
#
# -------------------------------------------------------

# %% [markdown]
# ## Model Mecric Report

# %%
model_metrics = pd.DataFrame(classification_report_dict)
model_metrics.loc['average'] = model_metrics.mean(axis = 0)
model_metrics['average'] = model_metrics.mean(axis = 1)
model_metrics.round(2)
# Out:
#             svm_nfp  svm_ros  svm_rus  xgb_nfp  xgb_ros  xgb_rus  average
# ccwt_model    78.79    64.44    70.00    78.79    77.78    70.00    73.30
# mca_model     62.50    61.54    58.33    78.12    76.92    62.50    66.65
# java_model    72.73    79.07    68.18    75.76    79.07    68.18    73.83
# ai_model      66.67    43.59    47.62    46.67    66.67    38.10    51.55
# pslb_model    63.64    52.63    66.67    66.67    60.53    62.96    62.18
# np_model      84.38    66.67    73.33    84.38    89.58    80.00    79.72
# dsa_model     60.61    65.85    62.50    60.61    70.73    66.67    64.50
# os_model      72.73    76.19    65.22    63.64    76.19    47.83    66.97
# cs_model      72.73    65.12    60.87    84.85    69.77    69.57    70.48
# deld_model    78.79    79.25    69.23    72.73    92.45    76.92    78.23
# cn_model      72.73    57.14    56.52    75.76    66.67    56.52    64.22
# cm_model      66.67    62.22    61.90    57.58    68.89    47.62    60.81
# iwt_model     76.67    29.17    33.33    66.67    64.58    41.67    52.02
# sepm_model    84.85    67.39    52.63    84.85    78.26    52.63    70.10
# imt_model     76.67    75.51    18.18    76.67    75.51    18.18    56.79
# dwt_model     46.67    63.64    59.26    66.67    57.58    59.26    58.85
# cc_model      71.88    58.97    45.83    46.88    58.97    41.67    54.03
# cg_model      60.61    72.73    59.38    63.64    60.61    40.62    59.60
# m3_model      69.70    75.76    71.88    66.67    75.76    53.12    68.82
# crp_model     68.75    55.81    66.67    68.75    62.79    57.14    63.32
# csa_model     66.67    66.67    62.07    63.64    69.44    58.62    64.52
# be_model      63.64    65.79    66.67    75.76    71.05    77.78    70.12
# ppc_model     65.62    77.27    50.00    78.12    77.27    60.00    68.05
# dms_model     57.58    67.50    60.00    69.70    65.00    48.00    61.30
# ada_model     72.73    60.61    59.38    63.64    48.48    68.75    62.27
# mp_model      78.79    75.00    79.31    75.76    72.22    62.07    73.86
# average       69.76    64.83    59.42    69.73    70.49    57.17    65.23

# %% [markdown]
# ## Sample Prediction

# %% [markdown]
# ### Function to predict result

# %%
def predict_my_result(sub_name, att, ct1, ct2, ta):
  model_name = '/content/models/' + sub_name + '_model.pkl'
  model = joblib.load(model_name)
  test_row = pd.DataFrame([[att, ct1, ct2, ta]], columns = ['att', 'ct1', 'ct2', 'ta'])
  return model.predict(test_row)[0]

# %% [markdown]
# ### Predict My Result

# %%
print('Subject keys : ')
print('cn', 'cm', 'be','dsa','cs','pslb','imt','mca','dms','java','cg','m3','ai','\niwt','np','dwt','cc','ccwt','os','sepm','ada','mp','deld','crp','csa','ppc')
sub_name = input('Enter the subject name : ')
att = int(input('Enter the attendence : '))
ct1 = int(input('Enter the marks obtained in ct 1 : '))
ct2 = int(input('Enter the marks obtained in ct 2 : '))
ta = int(input('Enter the marks obtained in ta : '))

result = predict_my_result(sub_name, att, ct1, ct2, ta)

if result == 1:
  print("Congratulations, you may pass")
else:
  print("Commiserations, you need to work harder")
# Out:
# Subject keys :
# cn cm be dsa cs pslb imt mca dms java cg m3 ai
# iwt np dwt cc ccwt os sepm ada mp deld crp csa ppc
# Enter the subject name : dsa
# Enter the attendence : 60
# Enter the marks obtained in ct 1 : 30
# Enter the marks obtained in ct 2 : 40
# Enter the marks obtained in ta : 12
# Commiseration, you need to work harder

# %% [markdown]
# # **End of File**
